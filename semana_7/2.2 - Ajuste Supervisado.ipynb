# %% [markdown]
# # 2.2 - Ajuste Supervisado
#
# ### GridSearching  -  CrossValidation
#
#
# ![grid](images/grid.png)
#
# ![cv](images/cv.ppm)

# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np


from sklearn.datasets import make_circles, load_boston

from sklearn.model_selection import train_test_split as tts

from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.ensemble import RandomForestClassifier as RFC

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
#help(RFR)

# %%
def grid(modelo, param, cv=5):
    
    g=GridSearchCV(modelo,   # modelo de sklearn
                   param,    # parametros, diccionario
                   cv=cv,    # cross-validation, 5 cortes(20%), train_test_split
                   return_train_score=True,  # para ver el error en el paquete de train
                   n_jobs=-1)  # para todas las cpus
                  
    
    g.fit(X_train, y_train)
    
    print('Acierto test: {:.2f}'.format(g.score(X_test, y_test)))
    print('Acierto train: {:.2f}'.format(g.score(X_train, y_train)))
    print('Mejores parametros: {}'.format(g.best_params_))
    print('Mejor acierto cv: {:.2f}'.format(g.best_score_))
    
    return g.best_estimator_.fit(X_train, y_train)  # mejor modelo encontrado ya entrenado

# %%
X_train, X_test, y_train, y_test = tts(load_boston().data, 
                                       load_boston().target, test_size=.2)

# %%
# %%time

rfr=RFR()

rfr.fit(X_train, y_train)


train_score=rfr.score(X_train, y_train)    # R2
test_score=rfr.score(X_test, y_test)

print (train_score, test_score)
# Out:
# 0.9836846885787353 0.8597771953558406
# CPU times: user 180 ms, sys: 3.48 ms, total: 183 ms
# Wall time: 181 ms

# %%
param={'n_estimators': [10, 50, 100, 150, 500],
       'max_depth': [1, 5, 10, 15, 20]}

# %%
# %%time

grid(rfr, param)
# Out:
# Acierto test: 0.86
# Acierto train: 0.99
# Mejores parametros: {'max_depth': 15, 'n_estimators': 100}
# Mejor acierto cv: 0.88
# CPU times: user 390 ms, sys: 16.8 ms, total: 407 ms
# Wall time: 4.75 s
# RandomForestRegressor(max_depth=15)

# %%
modelo=grid(rfr, param)
# Out:
# Acierto test: 0.85
# Acierto train: 0.98
# Mejores parametros: {'max_depth': 10, 'n_estimators': 100}
# Mejor acierto cv: 0.88

# %%
modelo.predict(X_test)[:5]
# Out:
# array([25.9082 , 29.3028 , 16.9786 , 24.19525, 12.1612 ])

# %% [markdown]
# ### Random GridSearching

# %%
X, y = make_circles(noise=0.2, factor=0.5, random_state=1)

# %%
import pylab as plt

plt.scatter(X[::, 0], X[::, 1], c=y);

# %%
n_estimators=[int(x) for x in np.linspace(200, 2000, 10)]

max_features=['auto', 'sqrt']

min_samples_split=[2, 5, 10]

bootstrap=[True, False]

# %%
params={'n_estimators': n_estimators,
        'max_features': max_features,
        'min_samples_split':min_samples_split,
        'bootstrap': bootstrap}

# %%
rfc=RFC()

# %%
rf_random=RandomizedSearchCV(estimator=rfc,
                             param_distributions=params,
                             n_iter=100,
                             cv=3,
                             verbose=10,
                             n_jobs=-1,
                             scoring='roc_auc')

# %%
rf_random.fit(X, y)   # ajustate para el mejor modelo
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    scoring='roc_auc', verbose=10)

# %%
rf_random.best_estimator_.fit(X, y)   # entrenar el mejor modelo
# Out:
# RandomForestClassifier(max_features='sqrt', n_estimators=400)

# %%
rf_random.best_score_
# Out:
# 0.8858491926182238

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'max_features': 'sqrt',
#  'bootstrap': True}

# %% [markdown]
# ### HyperOpt (GridSearching bayesiano)

# %%
# !pip install hyperopt

# %%
import pandas as pd
from pandas.plotting import scatter_matrix

import statsmodels.api as sm
from statsmodels.formula.api import ols

import xgboost as xgb

from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK

from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split as tts

# %%
df=pd.read_csv('../data/diamonds_train.csv')
df=df.dropna()

df.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %%
scatter_matrix(df, figsize=(15, 15));

# %%
X=df.drop('price', axis=1)

y=df.price

# %%
x=sm.add_constant(X._get_numeric_data())  # regresion lineal

modelo=sm.OLS(y, x).fit()

# %%
pred=modelo.predict(x)

modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                 4.136e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        12:00:58   Log-Likelihood:            -3.5311e+05
# No. Observations:               40455   AIC:                         7.062e+05
# Df Residuals:                   40448   BIC:                         7.063e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.152e+04    576.435     37.339      0.000    2.04e+04    2.27e+04
# carat       1.067e+04     73.530    145.064      0.000    1.05e+04    1.08e+04
# depth       -214.5839      7.619    -28.166      0.000    -229.516    -199.651
# table       -101.8176      3.555    -28.639      0.000    -108.786     -94.849
# x          -1343.8074     62.684    -21.438      0.000   -1466.669   -1220.946
# y             42.9796     29.273      1.468      0.142     -14.396     100.355
# z            126.9522     88.089      1.441      0.150     -45.705     299.609
# ==============================================================================
# Omnibus:                    10240.714   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           241364.592
# Skew:                           0.670   Prob(JB):                         0.00
# Kurtosis:                      14.891   Cond. No.                     6.62e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# [CV 2/3; 1/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200
# [CV 2/3; 1/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=0.884 total time=   0.2s
# [CV 2/3; 5/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=800
# [CV 2/3; 5/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=800;, score=0.873 total time=   0.5s
# [CV 3/3; 7/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=600
# [CV 3/3; 7/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=600;, score=0.960 total time=   0.4s
# [CV 1/3; 8/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1400
# [CV 1/3; 8/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1400;, score=0.806 total time=   0.7s
# [CV 2/3; 12/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1800
# [CV 2/3; 12/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1800;, score=0.827 total time=   0.9s
# [CV 3/3; 12/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1800
# [CV 3/3; 12/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1800;, score=0.926 total time=   0.9s
# [CV 2/3; 18/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=600
# [CV 2/3; 18/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=600;, score=0.879 total time=   0.4s
# [CV 3/3; 18/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=600
# [CV 3/3; 18/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=600;, score=0.945 total time=   0.4s
# [CV 1/3; 21/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=800
# [CV 1/3; 21/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=800;, score=0.792 total time=   0.5s
# [CV 2/3; 21/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=800
# [CV 2/3; 21/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=800;, score=0.864 total time=   0.5s
# [CV 3/3; 23/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=600
# [CV 3/3; 23/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=600;, score=0.930 total time=   0.3s
# [CV 3/3; 24/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1200
# [CV 3/3; 24/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1200;, score=0.960 total time=   0.8s
# [CV 1/3; 27/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=800
# [CV 1/3; 27/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=800;, score=0.808 total time=   0.4s
# [CV 3/3; 30/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200
# [CV 3/3; 30/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.960 total time=   0.1s
# [CV 1/3; 32/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200
# [CV 1/3; 32/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=0.782 total time=   0.1s
# [CV 2/3; 32/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200
# [CV 2/3; 32/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=0.838 total time=   0.1s
# [CV 1/3; 33/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=600
# [CV 1/3; 33/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=600;, score=0.796 total time=   0.4s
# [CV 3/3; 34/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1200
# [CV 3/3; 34/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1200;, score=0.949 total time=   0.8s
# [CV 3/3; 37/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1400
# [CV 3/3; 37/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1400;, score=0.945 total time=   0.9s
# [CV 3/3; 40/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=2000
# [CV 3/3; 40/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=2000;, score=0.886 total time=   1.0s
# [CV 2/3; 44/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=800
# [CV 2/3; 44/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=800;, score=0.822 total time=   0.4s
# [CV 2/3; 45/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 2/3; 45/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.811 total time=   0.1s
# [CV 2/3; 46/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=800
# [CV 2/3; 46/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=800;, score=0.814 total time=   0.4s
# [CV 1/3; 49/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=600
# [CV 1/3; 49/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=600;, score=0.799 total time=   0.4s
# [CV 1/3; 50/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 1/3; 50/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.792 total time=   0.4s
# [CV 2/3; 53/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=800
# [CV 2/3; 53/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=800;, score=0.864 total time=   0.5s
# [CV 2/3; 55/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1800
# [CV 2/3; 55/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1800;, score=0.822 total time=   0.9s
# [CV 2/3; 58/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=400
# [CV 2/3; 58/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=400;, score=0.879 total time=   0.3s
# [CV 1/3; 60/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1600
# [CV 1/3; 60/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1600;, score=0.791 total time=   0.8s
# [CV 3/3; 62/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1800
# [CV 3/3; 62/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1800;, score=0.926 total time=   0.9s
# [CV 2/3; 67/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200
# [CV 2/3; 67/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=0.835 total time=   0.1s
# [CV 1/3; 68/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1800
# [CV 1/3; 68/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1800;, score=0.830 total time=   1.2s
# [CV 1/3; 72/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1200
# [CV 1/3; 72/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1200;, score=0.806 total time=   0.6s
# [CV 3/3; 73/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1600
# [CV 3/3; 73/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1600;, score=0.956 total time=   1.1s
# [CV 3/3; 80/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 3/3; 80/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.923 total time=   0.2s
# [CV 1/3; 82/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=400
# [CV 1/3; 82/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=400;, score=0.810 total time=   0.2s
# [CV 3/3; 82/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=400
# [CV 3/3; 82/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=400;, score=0.888 total time=   0.2s
# [CV 1/3; 85/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=600
# [CV 1/3; 85/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=600;, score=0.808 total time=   0.3s
# [CV 1/3; 86/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1800
# [CV 1/3; 86/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1800;, score=0.792 total time=   1.2s
# [CV 3/3; 88/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1600
# [CV 3/3; 88/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1600;, score=0.923 total time=   0.8s
# [CV 2/3; 92/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1800
# [CV 2/3; 92/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1800;, score=0.860 total time=   1.2s
# [CV 1/3; 96/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=600
# [CV 1/3; 96/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=600;, score=0.799 total time=   0.4s
# [CV 1/3; 98/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1400
# [CV 1/3; 98/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1400;, score=0.811 total time=   0.7s
# [CV 2/3; 3/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=2000
# [CV 2/3; 3/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=2000;, score=0.860 total time=   1.4s
# [CV 3/3; 9/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1800
# [CV 3/3; 9/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1800;, score=0.888 total time=   0.9s
# [CV 1/3; 10/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=600
# [CV 1/3; 10/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=600;, score=0.811 total time=   0.3s
# [CV 2/3; 14/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=600
# [CV 2/3; 14/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=600;, score=0.811 total time=   0.3s
# [CV 3/3; 14/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=600
# [CV 3/3; 14/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=600;, score=0.923 total time=   0.3s
# [CV 1/3; 17/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=2000
# [CV 1/3; 17/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=2000;, score=0.834 total time=   1.3s
# [CV 2/3; 17/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=2000
# [CV 2/3; 17/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=2000;, score=0.864 total time=   1.3s
# [CV 1/3; 25/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1400
# [CV 1/3; 25/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1400;, score=0.796 total time=   0.9s
# [CV 3/3; 29/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1600
# [CV 3/3; 29/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1600;, score=0.923 total time=   0.8s
# [CV 2/3; 34/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1200
# [CV 2/3; 34/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1200;, score=0.875 total time=   0.8s
# [CV 1/3; 37/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1400
# [CV 1/3; 37/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1400;, score=0.824 total time=   1.0s
# [CV 2/3; 40/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=2000
# [CV 2/3; 40/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=2000;, score=0.846 total time=   1.0s
# [CV 1/3; 44/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=800
# [CV 1/3; 44/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=800;, score=0.804 total time=   0.4s
# [CV 1/3; 45/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 1/3; 45/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.798 total time=   0.1s
# [CV 1/3; 46/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=800
# [CV 1/3; 46/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=800;, score=0.787 total time=   0.4s
# [CV 3/3; 48/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1000
# [CV 3/3; 48/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1000;, score=0.926 total time=   0.5s
# [CV 1/3; 52/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1200
# [CV 1/3; 52/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1200;, score=0.799 total time=   0.8s
# [CV 1/3; 55/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1800
# [CV 1/3; 55/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1800;, score=0.808 total time=   0.9s
# [CV 3/3; 58/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=400
# [CV 3/3; 58/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=400;, score=0.960 total time=   0.3s
# [CV 2/3; 60/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1600
# [CV 2/3; 60/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1600;, score=0.814 total time=   0.8s
# [CV 1/3; 63/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=800
# [CV 1/3; 63/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=800;, score=0.824 total time=   0.5s
# [CV 1/3; 65/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1600
# [CV 1/3; 65/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1600;, score=0.827 total time=   1.1s
# [CV 3/3; 69/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1600
# [CV 3/3; 69/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1600;, score=0.949 total time=   1.1s
# [CV 2/3; 73/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1600
# [CV 2/3; 73/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1600;, score=0.871 total time=   1.0s
# [CV 1/3; 79/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1000
# [CV 1/3; 79/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1000;, score=0.824 total time=   0.7s
# [CV 1/3; 83/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=2000
# [CV 1/3; 83/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=2000;, score=0.804 total time=   0.9s
# [CV 3/3; 87/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=2000
# [CV 3/3; 87/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=2000;, score=0.886 total time=   1.0s
# [CV 1/3; 91/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1000
# [CV 1/3; 91/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1000;, score=0.799 total time=   0.6s
# [CV 3/3; 92/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1800
# [CV 3/3; 92/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1800;, score=0.952 total time=   1.2s
# [CV 2/3; 96/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=600
# [CV 2/3; 96/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=600;, score=0.860 total time=   0.4s
# [CV 1/3; 99/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1200
# [CV 1/3; 99/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1200;, score=0.808 total time=   0.7s
# [CV 3/3; 1/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200
# [CV 3/3; 1/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=0.949 total time=   0.1s
# [CV 1/3; 5/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=800
# [CV 1/3; 5/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=800;, score=0.827 total time=   0.5s
# [CV 1/3; 7/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=600
# [CV 1/3; 7/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=600;, score=0.799 total time=   0.4s
# [CV 2/3; 7/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=600
# [CV 2/3; 7/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=600;, score=0.864 total time=   0.5s
# [CV 1/3; 11/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1400
# [CV 1/3; 11/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1400;, score=0.811 total time=   0.7s
# [CV 2/3; 11/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1400
# [CV 2/3; 11/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1400;, score=0.822 total time=   0.7s
# [CV 1/3; 15/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1200
# [CV 1/3; 15/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1200;, score=0.813 total time=   0.8s
# [CV 2/3; 15/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1200
# [CV 2/3; 15/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1200;, score=0.849 total time=   0.8s
# [CV 3/3; 21/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=800
# [CV 3/3; 21/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=800;, score=0.952 total time=   0.5s
# [CV 1/3; 22/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=2000
# [CV 1/3; 22/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=2000;, score=0.832 total time=   1.3s
# [CV 1/3; 26/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=400
# [CV 1/3; 26/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=400;, score=0.811 total time=   0.2s
# [CV 3/3; 27/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=800
# [CV 3/3; 27/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=800;, score=0.886 total time=   0.4s
# [CV 1/3; 30/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200
# [CV 1/3; 30/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.803 total time=   0.1s
# [CV 2/3; 31/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1800
# [CV 2/3; 31/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1800;, score=0.811 total time=   0.9s
# [CV 2/3; 35/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1600
# [CV 2/3; 35/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1600;, score=0.864 total time=   1.1s
# [CV 2/3; 39/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=600
# [CV 2/3; 39/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=600;, score=0.818 total time=   0.3s
# [CV 1/3; 40/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=2000
# [CV 1/3; 40/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=2000;, score=0.810 total time=   1.0s
# [CV 2/3; 43/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1400
# [CV 2/3; 43/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1400;, score=0.862 total time=   0.9s
# [CV 3/3; 47/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1200
# [CV 3/3; 47/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1200;, score=0.923 total time=   0.6s
# [CV 3/3; 51/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=800
# [CV 3/3; 51/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=800;, score=0.886 total time=   0.4s
# [CV 1/3; 54/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1600
# [CV 1/3; 54/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1600;, score=0.806 total time=   0.8s
# [CV 3/3; 56/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=2000
# [CV 3/3; 56/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=2000;, score=0.956 total time=   1.4s
# [CV 2/3; 62/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1800
# [CV 2/3; 62/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1800;, score=0.814 total time=   0.9s
# [CV 3/3; 65/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1600
# [CV 3/3; 65/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1600;, score=0.945 total time=   1.1s
# [CV 2/3; 70/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=400
# [CV 2/3; 70/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=400;, score=0.816 total time=   0.2s
# [CV 1/3; 71/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1400
# [CV 1/3; 71/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1400;, score=0.796 total time=   0.9s
# [CV 2/3; 74/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 2/3; 74/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.875 total time=   0.1s
# [CV 2/3; 75/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1000
# [CV 2/3; 75/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1000;, score=0.814 total time=   0.5s
# [CV 2/3; 77/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200
# [CV 2/3; 77/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.858 total time=   0.1s
# [CV 2/3; 78/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 2/3; 78/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.853 total time=   0.1s
# [CV 3/3; 79/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1000
# [CV 3/3; 79/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1000;, score=0.941 total time=   0.6s
# [CV 2/3; 83/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=2000
# [CV 2/3; 83/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=2000;, score=0.822 total time=   1.0s
# [CV 1/3; 88/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1600
# [CV 1/3; 88/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1600;, score=0.787 total time=   0.8s
# [CV 2/3; 89/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1200
# [CV 2/3; 89/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1200;, score=0.814 total time=   0.6s
# [CV 1/3; 92/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1800
# [CV 1/3; 92/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1800;, score=0.796 total time=   1.2s
# [CV 1/3; 95/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=400
# [CV 1/3; 95/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=400;, score=0.832 total time=   0.3s
# [CV 2/3; 97/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1000
# [CV 2/3; 97/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1000;, score=0.846 total time=   0.5s
# [CV 2/3; 99/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1200
# [CV 2/3; 99/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1200;, score=0.822 total time=   0.6s
# [CV 3/3; 2/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200
# [CV 3/3; 2/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.881 total time=   0.1s
# [CV 3/3; 3/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=2000
# [CV 3/3; 3/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=2000;, score=0.956 total time=   1.3s
# [CV 2/3; 10/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=600
# [CV 2/3; 10/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=600;, score=0.842 total time=   0.3s
# [CV 3/3; 10/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=600
# [CV 3/3; 10/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=600;, score=0.886 total time=   0.3s
# [CV 1/3; 13/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=2000
# [CV 1/3; 13/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=2000;, score=0.796 total time=   1.3s
# [CV 2/3; 13/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=2000
# [CV 2/3; 13/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=2000;, score=0.864 total time=   1.3s
# [CV 2/3; 22/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=2000
# [CV 2/3; 22/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=2000;, score=0.858 total time=   1.3s
# [CV 2/3; 25/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1400
# [CV 2/3; 25/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1400;, score=0.860 total time=   1.0s
# [CV 1/3; 31/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1800
# [CV 1/3; 31/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1800;, score=0.791 total time=   0.9s
# [CV 3/3; 35/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1600
# [CV 3/3; 35/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1600;, score=0.960 total time=   1.0s
# [CV 1/3; 39/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=600
# [CV 1/3; 39/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=600;, score=0.804 total time=   0.3s
# [CV 3/3; 39/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=600
# [CV 3/3; 39/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=600;, score=0.926 total time=   0.3s
# [CV 3/3; 41/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1200
# [CV 3/3; 41/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1200;, score=0.963 total time=   0.8s
# [CV 3/3; 43/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1400
# [CV 3/3; 43/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1400;, score=0.949 total time=   0.9s
# [CV 2/3; 48/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1000
# [CV 2/3; 48/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1000;, score=0.822 total time=   0.5s
# [CV 1/3; 51/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=800
# [CV 1/3; 51/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=800;, score=0.811 total time=   0.4s
# [CV 3/3; 53/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=800
# [CV 3/3; 53/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=800;, score=0.960 total time=   0.6s
# [CV 3/3; 55/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1800
# [CV 3/3; 55/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1800;, score=0.930 total time=   0.9s
# [CV 2/3; 59/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=400
# [CV 2/3; 59/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=400;, score=0.864 total time=   0.3s
# [CV 1/3; 61/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=2000
# [CV 1/3; 61/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=2000;, score=0.787 total time=   1.0s
# [CV 3/3; 63/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=800
# [CV 3/3; 63/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=800;, score=0.945 total time=   0.5s
# [CV 1/3; 67/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200
# [CV 1/3; 67/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=0.811 total time=   0.1s
# [CV 3/3; 67/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200
# [CV 3/3; 67/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=0.884 total time=   0.1s
# [CV 2/3; 68/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1800
# [CV 2/3; 68/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1800;, score=0.864 total time=   1.2s
# [CV 2/3; 72/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1200
# [CV 2/3; 72/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1200;, score=0.842 total time=   0.6s
# [CV 1/3; 74/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 1/3; 74/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.799 total time=   0.1s
# [CV 1/3; 75/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1000
# [CV 1/3; 75/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1000;, score=0.791 total time=   0.5s
# [CV 1/3; 77/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200
# [CV 1/3; 77/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.832 total time=   0.1s
# [CV 1/3; 78/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 1/3; 78/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.789 total time=   0.1s
# [CV 2/3; 79/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1000
# [CV 2/3; 79/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1000;, score=0.864 total time=   0.7s
# [CV 1/3; 84/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1000
# [CV 1/3; 84/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1000;, score=0.792 total time=   0.7s
# [CV 2/3; 86/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1800
# [CV 2/3; 86/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1800;, score=0.857 total time=   1.2s
# [CV 2/3; 90/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1600
# [CV 2/3; 90/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1600;, score=0.868 total time=   1.0s
# [CV 2/3; 93/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1200
# [CV 2/3; 93/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1200;, score=0.838 total time=   0.6s
# [CV 3/3; 95/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=400
# [CV 3/3; 95/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=400;, score=0.945 total time=   0.3s
# [CV 3/3; 96/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=600
# [CV 3/3; 96/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=600;, score=0.960 total time=   0.4s
# [CV 3/3; 98/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1400
# [CV 3/3; 98/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1400;, score=0.926 total time=   0.8s
# [CV 1/3; 3/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=2000
# [CV 1/3; 3/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=2000;, score=0.799 total time=   1.3s
# [CV 1/3; 9/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1800
# [CV 1/3; 9/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1800;, score=0.806 total time=   0.9s
# [CV 2/3; 9/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1800
# [CV 2/3; 9/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1800;, score=0.846 total time=   0.9s
# [CV 2/3; 16/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 2/3; 16/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.857 total time=   0.3s
# [CV 3/3; 16/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 3/3; 16/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.956 total time=   0.3s
# [CV 1/3; 19/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1400
# [CV 1/3; 19/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1400;, score=0.810 total time=   0.7s
# [CV 2/3; 19/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1400
# [CV 2/3; 19/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1400;, score=0.846 total time=   0.7s
# [CV 1/3; 23/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=600
# [CV 1/3; 23/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=600;, score=0.791 total time=   0.3s
# [CV 2/3; 23/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=600
# [CV 2/3; 23/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=600;, score=0.814 total time=   0.3s
# [CV 1/3; 24/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1200
# [CV 1/3; 24/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1200;, score=0.796 total time=   0.8s
# [CV 2/3; 26/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=400
# [CV 2/3; 26/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=400;, score=0.814 total time=   0.2s
# [CV 1/3; 28/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200
# [CV 1/3; 28/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=0.784 total time=   0.1s
# [CV 2/3; 28/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200
# [CV 2/3; 28/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=0.818 total time=   0.1s
# [CV 1/3; 29/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1600
# [CV 1/3; 29/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1600;, score=0.808 total time=   0.8s
# [CV 3/3; 33/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=600
# [CV 3/3; 33/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=600;, score=0.952 total time=   0.4s
# [CV 1/3; 36/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=800
# [CV 1/3; 36/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=800;, score=0.792 total time=   0.5s
# [CV 2/3; 37/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1400
# [CV 2/3; 37/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1400;, score=0.875 total time=   1.0s
# [CV 2/3; 41/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1200
# [CV 2/3; 41/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1200;, score=0.857 total time=   0.8s
# [CV 3/3; 42/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=2000
# [CV 3/3; 42/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=2000;, score=0.923 total time=   1.0s
# [CV 1/3; 48/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1000
# [CV 1/3; 48/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1000;, score=0.801 total time=   0.5s
# [CV 3/3; 49/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=600
# [CV 3/3; 49/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=600;, score=0.963 total time=   0.4s
# [CV 1/3; 53/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=800
# [CV 1/3; 53/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=800;, score=0.792 total time=   0.5s
# [CV 3/3; 54/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1600
# [CV 3/3; 54/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1600;, score=0.886 total time=   0.8s
# [CV 3/3; 57/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 3/3; 57/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.926 total time=   0.2s
# [CV 1/3; 59/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=400
# [CV 1/3; 59/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=400;, score=0.799 total time=   0.3s
# [CV 3/3; 60/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1600
# [CV 3/3; 60/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1600;, score=0.923 total time=   0.8s
# [CV 2/3; 63/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=800
# [CV 2/3; 63/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=800;, score=0.869 total time=   0.5s
# [CV 2/3; 65/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1600
# [CV 2/3; 65/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1600;, score=0.864 total time=   1.1s
# [CV 1/3; 70/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=400
# [CV 1/3; 70/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=400;, score=0.782 total time=   0.2s
# [CV 3/3; 70/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=400
# [CV 3/3; 70/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=400;, score=0.926 total time=   0.2s
# [CV 2/3; 71/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1400
# [CV 2/3; 71/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1400;, score=0.864 total time=   0.9s
# [CV 3/3; 75/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1000
# [CV 3/3; 75/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1000;, score=0.934 total time=   0.5s
# [CV 3/3; 77/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200
# [CV 3/3; 77/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.941 total time=   0.2s
# [CV 3/3; 78/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 3/3; 78/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.945 total time=   0.1s
# [CV 1/3; 80/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 1/3; 80/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.801 total time=   0.2s
# [CV 2/3; 81/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1200
# [CV 2/3; 81/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1200;, score=0.814 total time=   0.5s
# [CV 2/3; 84/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1000
# [CV 2/3; 84/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1000;, score=0.864 total time=   0.6s
# [CV 3/3; 86/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1800
# [CV 3/3; 86/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1800;, score=0.960 total time=   1.2s
# [CV 3/3; 90/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1600
# [CV 3/3; 90/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1600;, score=0.960 total time=   1.0s
# [CV 3/3; 93/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1200
# [CV 3/3; 93/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1200;, score=0.886 total time=   0.6s
# [CV 2/3; 95/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=400
# [CV 2/3; 95/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=400;, score=0.881 total time=   0.3s
# [CV 1/3; 97/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1000
# [CV 1/3; 97/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1000;, score=0.811 total time=   0.5s
# [CV 3/3; 99/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1200
# [CV 3/3; 99/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1200;, score=0.926 total time=   0.6s
# [CV 1/3; 1/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200
# [CV 1/3; 1/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=0.817 total time=   0.1s
# [CV 3/3; 4/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=400
# [CV 3/3; 4/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=400;, score=0.884 total time=   0.2s
# [CV 2/3; 6/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=2000
# [CV 2/3; 6/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=2000;, score=0.860 total time=   1.3s
# [CV 3/3; 6/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=2000
# [CV 3/3; 6/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=2000;, score=0.960 total time=   1.3s
# [CV 3/3; 15/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1200
# [CV 3/3; 15/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1200;, score=0.952 total time=   0.8s
# [CV 1/3; 16/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 1/3; 16/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.785 total time=   0.3s
# [CV 2/3; 20/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1800
# [CV 2/3; 20/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1800;, score=0.868 total time=   1.2s
# [CV 3/3; 20/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1800
# [CV 3/3; 20/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1800;, score=0.960 total time=   1.2s
# [CV 3/3; 26/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=400
# [CV 3/3; 26/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=400;, score=0.926 total time=   0.2s
# [CV 3/3; 28/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200
# [CV 3/3; 28/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=0.926 total time=   0.1s
# ...
# [CV 1/3; 6/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=2000;, score=0.792 total time=   1.3s
# [CV 3/3; 11/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1400
# [CV 3/3; 11/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1400;, score=0.934 total time=   0.7s
# [CV 1/3; 12/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1800
# [CV 1/3; 12/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=1800;, score=0.811 total time=   0.9s
# [CV 3/3; 17/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=2000
# [CV 3/3; 17/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=2000;, score=0.941 total time=   1.3s
# [CV 1/3; 18/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=600
# [CV 1/3; 18/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=600;, score=0.830 total time=   0.4s
# [CV 3/3; 22/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=2000
# [CV 3/3; 22/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=2000;, score=0.949 total time=   1.4s
# [CV 3/3; 25/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1400
# [CV 3/3; 25/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1400;, score=0.952 total time=   1.0s
# [CV 3/3; 32/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200
# [CV 3/3; 32/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=0.956 total time=   0.1s
# [CV 2/3; 33/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=600
# [CV 2/3; 33/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=600;, score=0.849 total time=   0.4s
# [CV 1/3; 35/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1600
# [CV 1/3; 35/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1600;, score=0.789 total time=   1.1s
# [CV 2/3; 38/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1400
# [CV 2/3; 38/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1400;, score=0.842 total time=   0.9s
# [CV 1/3; 42/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=2000
# [CV 1/3; 42/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=2000;, score=0.787 total time=   1.0s
# [CV 3/3; 44/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=800
# [CV 3/3; 44/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=800;, score=0.930 total time=   0.4s
# [CV 2/3; 47/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1200
# [CV 2/3; 47/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1200;, score=0.818 total time=   0.6s
# [CV 2/3; 51/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=800
# [CV 2/3; 51/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=800;, score=0.842 total time=   0.4s
# [CV 2/3; 54/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1600
# [CV 2/3; 54/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1600;, score=0.846 total time=   0.9s
# [CV 1/3; 57/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 1/3; 57/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.811 total time=   0.2s
# [CV 2/3; 57/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 2/3; 57/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.822 total time=   0.2s
# [CV 1/3; 58/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=400
# [CV 1/3; 58/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=400;, score=0.803 total time=   0.3s
# [CV 3/3; 59/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=400
# [CV 3/3; 59/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=400;, score=0.963 total time=   0.3s
# [CV 2/3; 61/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=2000
# [CV 2/3; 61/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=2000;, score=0.814 total time=   1.0s
# [CV 1/3; 64/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=600
# [CV 1/3; 64/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=600;, score=0.791 total time=   0.3s
# [CV 1/3; 66/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=800
# [CV 1/3; 66/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=800;, score=0.787 total time=   0.4s
# [CV 3/3; 68/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1800
# [CV 3/3; 68/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=1800;, score=0.949 total time=   1.3s
# [CV 1/3; 73/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1600
# [CV 1/3; 73/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1600;, score=0.796 total time=   1.0s
# [CV 3/3; 76/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1600
# [CV 3/3; 76/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1600;, score=0.886 total time=   0.8s
# [CV 2/3; 82/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=400
# [CV 2/3; 82/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=400;, score=0.846 total time=   0.2s
# [CV 3/3; 83/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=2000
# [CV 3/3; 83/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=2000;, score=0.926 total time=   1.0s
# [CV 2/3; 88/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1600
# [CV 2/3; 88/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1600;, score=0.814 total time=   0.8s
# [CV 1/3; 90/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1600
# [CV 1/3; 90/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1600;, score=0.792 total time=   1.0s
# [CV 1/3; 93/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1200
# [CV 1/3; 93/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1200;, score=0.811 total time=   0.6s
# [CV 3/3; 94/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1600
# [CV 3/3; 94/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1600;, score=0.952 total time=   1.1s
# [CV 1/3; 100/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1400
# [CV 1/3; 100/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1400;, score=0.799 total time=   0.8s
# [CV 1/3; 2/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200
# [CV 1/3; 2/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.813 total time=   0.1s
# [CV 1/3; 4/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=400
# [CV 1/3; 4/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=400;, score=0.815 total time=   0.2s
# [CV 3/3; 5/100] START bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=800
# [CV 3/3; 5/100] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=800;, score=0.938 total time=   0.5s
# [CV 2/3; 8/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1400
# [CV 2/3; 8/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1400;, score=0.846 total time=   0.7s
# [CV 3/3; 8/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1400
# [CV 3/3; 8/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1400;, score=0.886 total time=   0.7s
# [CV 3/3; 13/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=2000
# [CV 3/3; 13/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=2000;, score=0.960 total time=   1.4s
# [CV 1/3; 14/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=600
# [CV 1/3; 14/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=600;, score=0.791 total time=   0.3s
# [CV 3/3; 19/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1400
# [CV 3/3; 19/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1400;, score=0.886 total time=   0.7s
# [CV 1/3; 20/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1800
# [CV 1/3; 20/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1800;, score=0.799 total time=   1.2s
# [CV 2/3; 24/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1200
# [CV 2/3; 24/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1200;, score=0.860 total time=   0.8s
# [CV 2/3; 27/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=800
# [CV 2/3; 27/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=800;, score=0.840 total time=   0.4s
# [CV 2/3; 30/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200
# [CV 2/3; 30/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.857 total time=   0.1s
# [CV 3/3; 31/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1800
# [CV 3/3; 31/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1800;, score=0.926 total time=   0.9s
# [CV 2/3; 36/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=800
# [CV 2/3; 36/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=800;, score=0.860 total time=   0.5s
# [CV 1/3; 38/100] START bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1400
# [CV 1/3; 38/100] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=1400;, score=0.799 total time=   0.9s
# [CV 1/3; 41/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1200
# [CV 1/3; 41/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1200;, score=0.799 total time=   0.8s
# [CV 1/3; 43/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1400
# [CV 1/3; 43/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1400;, score=0.824 total time=   0.9s
# [CV 1/3; 47/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1200
# [CV 1/3; 47/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=1200;, score=0.787 total time=   0.6s
# [CV 2/3; 50/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 2/3; 50/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.864 total time=   0.2s
# [CV 2/3; 52/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1200
# [CV 2/3; 52/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=1200;, score=0.864 total time=   0.8s
# [CV 1/3; 56/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=2000
# [CV 1/3; 56/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=2000;, score=0.792 total time=   1.4s
# [CV 3/3; 61/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=2000
# [CV 3/3; 61/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=2000;, score=0.926 total time=   1.0s
# [CV 3/3; 64/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=600
# [CV 3/3; 64/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=600;, score=0.930 total time=   0.3s
# [CV 3/3; 66/100] START bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=800
# [CV 3/3; 66/100] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=800;, score=0.926 total time=   0.4s
# [CV 2/3; 69/100] START bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1600
# [CV 2/3; 69/100] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=1600;, score=0.860 total time=   1.1s
# [CV 3/3; 72/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1200
# [CV 3/3; 72/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=1200;, score=0.882 total time=   0.7s
# [CV 3/3; 74/100] START bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 3/3; 74/100] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.952 total time=   0.1s
# [CV 1/3; 76/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1600
# [CV 1/3; 76/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=1600;, score=0.810 total time=   0.8s
# [CV 2/3; 80/100] START bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 2/3; 80/100] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.825 total time=   0.2s
# [CV 3/3; 81/100] START bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1200
# [CV 3/3; 81/100] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=1200;, score=0.923 total time=   0.6s
# [CV 2/3; 85/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=600
# [CV 2/3; 85/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=600;, score=0.842 total time=   0.3s
# [CV 3/3; 85/100] START bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=600
# [CV 3/3; 85/100] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=600;, score=0.886 total time=   0.3s
# [CV 2/3; 87/100] START bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=2000
# [CV 2/3; 87/100] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=2000;, score=0.846 total time=   1.0s
# [CV 3/3; 89/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1200
# [CV 3/3; 89/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1200;, score=0.923 total time=   0.6s
# [CV 2/3; 91/100] START bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1000
# [CV 2/3; 91/100] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=1000;, score=0.868 total time=   0.6s
# [CV 1/3; 94/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1600
# [CV 1/3; 94/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1600;, score=0.796 total time=   1.1s
# [CV 2/3; 98/100] START bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1400
# [CV 2/3; 98/100] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=1400;, score=0.827 total time=   0.7s
# [CV 3/3; 100/100] START bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1400
# [CV 3/3; 100/100] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=1400;, score=0.952 total time=   0.7s

# %%
X=X.drop(['y', 'z'], axis=1)

# %%
x=sm.add_constant(X._get_numeric_data())  # regresion lineal

modelo=sm.OLS(y, x).fit()

pred=modelo.predict(x)

modelo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                 6.204e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        12:02:40   Log-Likelihood:            -3.5312e+05
# No. Observations:               40455   AIC:                         7.062e+05
# Df Residuals:                   40450   BIC:                         7.063e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.112e+04    483.507     43.690      0.000    2.02e+04    2.21e+04
# carat       1.067e+04     73.471    145.261      0.000    1.05e+04    1.08e+04
# depth       -207.5675      5.593    -37.110      0.000    -218.531    -196.604
# table       -102.1651      3.552    -28.762      0.000    -109.127     -95.203
# x          -1225.7240     31.053    -39.472      0.000   -1286.588   -1164.860
# ==============================================================================
# Omnibus:                    10244.858   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           241444.483
# Skew:                           0.670   Prob(JB):                         0.00
# Kurtosis:                      14.893   Cond. No.                     5.52e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.52e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
clarity={'I1':0, 'SI2':1, 'SI1':2, 'VS2':3, 'VS1':4,
         'VVS2':5, 'VVS1':6, 'IF':7}


cut={'Fair':0, 'Good':1, 'Very Good':2, 'Premium':3, 'Ideal':4}


color={'J':0, 'I':1, 'H':2, 'G':3, 'F':4, 'E':5, 'D':6}

# %%
def label(s, dic):
    return dic[s]

# %%
X.clarity=X.clarity.apply(lambda x: label(x, clarity))

X.cut=X.cut.apply(lambda x: label(x, cut))

X.color=X.color.apply(lambda x: label(x, color))

X.head()
# Out:
#    carat  cut  color  clarity  depth  table     x
# 0   1.21    3      0        3   62.4   58.0  6.83
# 1   0.32    2      2        3   63.0   57.0  4.35
# 2   0.71    0      3        4   65.5   55.0  5.62
# 3   0.41    1      6        2   63.8   56.0  4.68
# 4   1.02    4      3        2   60.5   59.0  6.55

# %%
X_train, X_test, y_train, y_test = tts(X, y, 
                                       test_size=0.2, 
                                       random_state=42)

# %%
modelo=xgb.XGBRegressor()

modelo.fit(X_train, y_train)

y_pred=modelo.predict(X_test)

mse(y_test, y_pred, squared=False)   # RMSE
# Out:
# 548.6528831793221

# %%
modelo
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
# aprioris

space={
    'n_estimators':hp.quniform('n_estimators', 10, 1000, 25),
    
    'learning_rate':hp.uniform('learning_rate', 0.0001, 1.0),
    
    'max_depth':hp.quniform('max_depth', 4, 16, 1),
    
    'min_child_weight':hp.quniform('min_child', 1, 10, 1),
    
    'subsample':hp.uniform('subsample', 0.7, 1),
    
    'gamma':hp.uniform('gamma', 0.1, 0.5),
    
    'reg_lambda':hp.uniform('reg_lambda', 0, 1)
}

# %%
def objetivo(space):
    
    modelo=xgb.XGBRegressor(
        
        n_estimators=int(space['n_estimators']),
        learning_rate=space['learning_rate'],
        max_depth=int(space['max_depth']),
        min_child_weight=space['min_child_weight'],
        subsample=space['subsample'],
        gamma=space['gamma'],
        reg_lambda=space['reg_lambda'],
        objective='reg:squarederror'
    )
    
    eval_set=[(X_train, y_train), (X_test, y_test)]
    
    modelo.fit(X_train, y_train, eval_set=eval_set, eval_metric='rmse', verbose=False)
    
    y_pred=modelo.predict(X_test)
    
    rmse=mse(y_test, y_pred, squared=False)
    
    return {'loss': rmse, 'status': STATUS_OK}

# %%
best=fmin(fn=objetivo,
          space=space,
          algo=tpe.suggest,
          max_evals=20,
          trials=Trials())

best
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 20/20 [02:27<00:00,  7.39s/trial, best loss: 546.4094249523108]
# {'gamma': 0.44828585468694304,
#  'learning_rate': 0.06943790365960119,
#  'max_depth': 4.0,
#  'min_child': 3.0,
#  'n_estimators': 825.0,
#  'reg_lambda': 0.3017286427178809,
#  'subsample': 0.847878135499621}

# %%
modelo=xgb.XGBRegressor(
    n_estimators=int(best['n_estimators']),
    learning_rate=best['learning_rate'],
    max_depth=int(best['max_depth']),
    subsample=best['subsample'],
    gamma=best['gamma'],
    reg_lambda=best['reg_lambda'],
    objective='reg:squarederror'
    )

# %%
modelo.fit(X_train, y_train)
y_pred=modelo.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 548.1339292906786

# %%
m=xgb.XGBRegressor()
m.fit(X_train, y_train)
y_pred=m.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 548.6528831793221

# %%
from sklearn.linear_model import LinearRegression

# %%
help(LinearRegression)
# Out:
# Help on class LinearRegression in module sklearn.linear_model._base:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, normalize='deprecated', copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  normalize : bool, default=False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
#  |      If True, the regressors X will be normalized before regression by
#  |      subtracting the mean and dividing by the l2-norm.
#  |      If you wish to standardize, please use
#  |      :class:`~sklearn.preprocessing.StandardScaler` before calling ``fit``
#  |      on an estimator with ``normalize=False``.
#  |
#  |      .. deprecated:: 1.0
#  |         `normalize` was deprecated in version 1.0 and will be
#  |         removed in 1.2.
#  |
#  |  copy_X : bool, default=True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
#  |  n_jobs : int, default=None
#  |      The number of jobs to use for the computation. This will only provide
#  |      speedup in case of sufficiently large problems, that is if firstly
#  |      `n_targets > 1` and secondly `X` is sparse or if `positive` is set
#  |      to `True`. ``None`` means 1 unless in a
#  |      :obj:`joblib.parallel_backend` context. ``-1`` means using all
#  |      processors. See :term:`Glossary <n_jobs>` for more details.
#  |
#  |  positive : bool, default=False
#  |      When set to ``True``, forces the coefficients to be positive. This
#  |      option is only supported for dense arrays.
#  |
#  |      .. versionadded:: 0.24
#  |
#  |  Attributes
#  |  ----------
#  |  coef_ : array of shape (n_features, ) or (n_targets, n_features)
#  |      Estimated coefficients for the linear regression problem.
#  |      If multiple targets are passed during the fit (y 2D), this
#  |      is a 2D array of shape (n_targets, n_features), while if only
#  |      one target is passed, this is a 1D array of length n_features.
#  |
#  |  rank_ : int
#  |      Rank of matrix `X`. Only available when `X` is dense.
#  |
#  |  singular_ : array of shape (min(X, y),)
#  |      Singular values of `X`. Only available when `X` is dense.
#  |
#  |  intercept_ : float or array of shape (n_targets,)
#  |      Independent term in the linear model. Set to 0.0 if
#  |      `fit_intercept = False`.
#  |
#  |  n_features_in_ : int
#  |      Number of features seen during :term:`fit`.
#  |
#  |      .. versionadded:: 0.24
#  |
#  |  feature_names_in_ : ndarray of shape (`n_features_in_`,)
#  |      Names of features seen during :term:`fit`. Defined only when `X`
#  |      has feature names that are all strings.
#  |
#  |      .. versionadded:: 1.0
#  |
#  |  See Also
#  |  --------
#  |  Ridge : Ridge regression addresses some of the
#  |      problems of Ordinary Least Squares by imposing a penalty on the
#  |      size of the coefficients with l2 regularization.
#  |  Lasso : The Lasso is a linear model that estimates
#  |      sparse coefficients with l1 regularization.
#  |  ElasticNet : Elastic-Net is a linear regression
#  |      model trained with both l1 and l2 -norm regularization of the
#  |      coefficients.
#  |
#  |  Notes
#  |  -----
#  |  From the implementation point of view, this is just plain Ordinary
#  |  Least Squares (scipy.linalg.lstsq) or Non Negative Least Squares
#  |  (scipy.optimize.nnls) wrapped as a predictor object.
#  |
#  |  Examples
#  |  --------
#  |  >>> import numpy as np
#  |  >>> from sklearn.linear_model import LinearRegression
#  |  >>> X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
#  |  >>> # y = 1 * x_0 + 2 * x_1 + 3
#  |  >>> y = np.dot(X, np.array([1, 2])) + 3
#  |  >>> reg = LinearRegression().fit(X, y)
#  |  >>> reg.score(X, y)
#  |  1.0
#  |  >>> reg.coef_
#  |  array([1., 2.])
#  |  >>> reg.intercept_
#  |  3.0...
#  |  >>> reg.predict(np.array([[3, 5]]))
#  |  array([16.])
#  |
#  |  Method resolution order:
#  |      LinearRegression
#  |      sklearn.base.MultiOutputMixin
#  |      sklearn.base.RegressorMixin
#  |      LinearModel
#  |      sklearn.base.BaseEstimator
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *, fit_intercept=True, normalize='deprecated', copy_X=True, n_jobs=None, positive=False)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  fit(self, X, y, sample_weight=None)
#  |      Fit linear model.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          Training data.
#  |
#  |      y : array-like of shape (n_samples,) or (n_samples, n_targets)
#  |          Target values. Will be cast to X's dtype if necessary.
#  |
#  |      sample_weight : array-like of shape (n_samples,), default=None
#  |          Individual weights for each sample.
#  |
#  |          .. versionadded:: 0.17
#  |             parameter *sample_weight* support to LinearRegression.
#  |
#  |      Returns
#  |      -------
#  |      self : object
#  |          Fitted Estimator.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from sklearn.base.MultiOutputMixin:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.RegressorMixin:
#  |
#  |  score(self, X, y, sample_weight=None)
#  |      Return the coefficient of determination of the prediction.
#  |
#  |      The coefficient of determination :math:`R^2` is defined as
#  |      :math:`(1 - \frac{u}{v})`, where :math:`u` is the residual
#  |      sum of squares ``((y_true - y_pred)** 2).sum()`` and :math:`v`
#  |      is the total sum of squares ``((y_true - y_true.mean()) ** 2).sum()``.
#  |      The best possible score is 1.0 and it can be negative (because the
#  |      model can be arbitrarily worse). A constant model that always predicts
#  |      the expected value of `y`, disregarding the input features, would get
#  |      a :math:`R^2` score of 0.0.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array-like of shape (n_samples, n_features)
#  |          Test samples. For some estimators this may be a precomputed
#  |          kernel matrix or a list of generic objects instead with shape
#  |          ``(n_samples, n_samples_fitted)``, where ``n_samples_fitted``
#  |          is the number of samples used in the fitting for the estimator.
#  |
#  |      y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#  |          True values for `X`.
#  |
#  |      sample_weight : array-like of shape (n_samples,), default=None
#  |          Sample weights.
#  |
#  |      Returns
#  |      -------
#  |      score : float
#  |          :math:`R^2` of ``self.predict(X)`` wrt. `y`.
#  |
#  |      Notes
#  |      -----
#  |      The :math:`R^2` score used when calling ``score`` on a regressor uses
#  |      ``multioutput='uniform_average'`` from version 0.23 to keep consistent
#  |      with default value of :func:`~sklearn.metrics.r2_score`.
#  |      This influences the ``score`` method of all the multioutput
#  |      regressors (except for
#  |      :class:`~sklearn.multioutput.MultiOutputRegressor`).
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from LinearModel:
#  |
#  |  predict(self, X)
#  |      Predict using the linear model.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array-like or sparse matrix, shape (n_samples, n_features)
#  |          Samples.
#  |
#  |      Returns
#  |      -------
#  |      C : array, shape (n_samples,)
#  |          Returns predicted values.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.BaseEstimator:
#  |
#  |  __getstate__(self)
#  |
#  |  __repr__(self, N_CHAR_MAX=700)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  get_params(self, deep=True)
#  |      Get parameters for this estimator.
#  |
#  |      Parameters
#  |      ----------
#  |      deep : bool, default=True
#  |          If True, will return the parameters for this estimator and
#  |          contained subobjects that are estimators.
#  |
#  |      Returns
#  |      -------
#  |      params : dict
#  |          Parameter names mapped to their values.
#  |
#  |  set_params(self, **params)
#  |      Set the parameters of this estimator.
#  |
#  |      The method works on simple estimators as well as on nested objects
#  |      (such as :class:`~sklearn.pipeline.Pipeline`). The latter have
#  |      parameters of the form ``<component>__<parameter>`` so that it's
#  |      possible to update each component of a nested object.
#  |
#  |      Parameters
#  |      ----------
#  |      **params : dict
#  |          Estimator parameters.
#  |
#  |      Returns
#  |      -------
#  |      self : estimator instance
#  |          Estimator instance.

# %% [markdown]
# # 2.1 - Testeo de hipótesis
#
# ##### Recordatorio
#
#
# + Población => Todos los elementos (normalmente desconocido)
# + Muestra => Subconjunto de la población
#
#
# **Método Científico**
#
# ![scientific_method](images/scientific_method.jpeg)

# %% [markdown]
# # Hipotesis

# %% [markdown]
# + **H0**
#
# Hipótesis nula. (H0). H0 es el status quo, el mainstream, la hipótesis a vencer por el investigador.
#
#
# + **H1**
#
# Hipótesis alternativa. (H1). H1 es la nueva hipótesis, la del investigador.

# %% [markdown]
# # Tipos de tests

# %% [markdown]
# **1)** (one-side)
#
# $$H0: \mu \geq k$$
# $$H1: \mu < k$$

# %% [markdown]
# **2)** (one-side)
#
# $$H0: \mu \leq k$$
# $$H1: \mu > k$$

# %% [markdown]
# **3)** (two-side)
#
# $$H0: \mu = k$$
# $$H1: \mu ≠ k$$

# %% [markdown]
# # Suposiciones para el testeo

# %% [markdown]
# **1)**
#
# Observaciones independientes. (Para evitar sesgos)

# %% [markdown]
# **2)**
#
# Normalidad de los datos. ($N(\mu, \sigma)$)
#
# Teorema Central del Limite (minimo tamaño de la muestra = 30)

# %% [markdown]
# **3)**
#
# Tamaño adecuado de la muestra.

# %% [markdown]
# **Tamaño de la muestra**
#
# https://es.wikipedia.org/wiki/Tama%C3%B1o_de_la_muestra

# %% [markdown]
# **4)**
#
# Para usar la $N(\mu, \sigma)$, debemos conocer $\sigma$ (desviacion estandar de la poblacion).Si $\sigma$ es desconocida, se usa la t-Student para el testeo de hipotesis, lo que implica usar s (desviacion estandar muestral, n-1).

# %% [markdown]
# # Test (estadistico)

# %% [markdown]
# + $N(\mu, \sigma)$ , $Z-test$
#
# $$z=\frac{\bar{x} - \mu}{\frac{\sigma}{\sqrt{n}}}$$
#
# donde:
# + $\bar{x}$ es la media muestral
# + $\mu$ es la media poblacional
# + $\sigma$ es la std poblacional
# + $\sqrt{n}$ es la raiz de n=tamaño de la muestra
# + $\frac{\sigma}{\sqrt{n}}$ se le llama error estandar

# %% [markdown]
# + t-Student , $t-test$
#
# $$t=\frac{\bar{x} - \mu}{\frac{s}{\sqrt{n}}}$$
#
# donde:
# + $\bar{x}$ es la media muestral
# + $\mu$ es la media poblacional
# + $s$ es la std muestral
# + $\sqrt{n}$ es la raiz de n=tamaño de la muestra
# + $\frac{s}{\sqrt{n}}$ se le llama error estandar muestral

# %% [markdown]
# # P-value

# %% [markdown]
# **p-value** = es la probabilidad correspondiente al estadistico de ser posible bajo H0.

# %% [markdown]
# $$pvalue > umbral => H0$$
# $$pvalue < umbral => H1$$

# %% [markdown]
# El umbral esta determinado por el intervalo de confianza.

# %%
import pylab as plt
from scipy.stats import norm

# %%
x=[i*.1 for i in range(-60, 60)]

y1=[norm.pdf(x, -2, 1) for x in x]
y2=[norm.pdf(x, 2, 1) for x in x]

# %%
# %matplotlib inline

plt.figure(figsize=(15, 8))
plt.plot(x, y1)
plt.plot(-2, max(y1)+.02, marker='$H1$', color='red', ms=20)
plt.plot(x, y2)
plt.plot(2, max(y2)+.02, marker='$H0$', color='blue', ms=20)

plt.quiver(1.5, 0.1, -1, -0.6, color='r', scale=10)  # para pintar una flecha

for i in range(49, 74):
    if y1[i]<=y2[i]:
        plt.bar(x[i], y1[i], width=0.1, color='r')
    else:
        plt.bar(x[i], y2[i], width=0.1, color='y')
        
plt.plot([0,0], [0, 0.5], color='r')
plt.title('H1: mu<k , H0: mu>=k', fontsize=18);

# %%
plt.figure(figsize=(15, 8))
plt.plot(x, y1)
plt.plot(-2, max(y1)+.02, marker='$H0$', color='red', ms=20)
plt.plot(x, y2)
plt.plot(2, max(y2)+.02, marker='$H1$', color='blue', ms=20)

plt.quiver(1.5, 0.1, -1, -0.6, color='r', scale=10)  # para pintar una flecha

for i in range(74):
    if y1[i]>y2[i]:
        plt.bar(x[i], y1[i], width=0.1, color='r')
        plt.bar(x[i], y2[i], width=0.1, color='y')
        
plt.plot([0,0], [0, 0.5], color='r')
plt.title('H1: mu>k , H0: mu<=k', fontsize=18);

# %%
y1=[norm.pdf(x, -.5, 1) for x in x]
y2=[norm.pdf(x, .5, 1) for x in x]

plt.figure(figsize=(15, 8))
plt.plot(x, y1)
plt.plot(-2, max(y1)+.02, marker='$H0$', color='red', ms=20)
plt.plot(x, y2)
plt.plot(2, max(y2)+.02, marker='$H1$', color='blue', ms=20)

plt.quiver(1.5, 0.08, 1, -0.6, color='y', scale=20)  # para pintar una flecha
plt.quiver(-1.5, 0.09, -1, -0.6, color='y', scale=20)

for i in range(85, 100):
    if y1[i]<=y2[i]:
        plt.bar(x[i], y2[i], width=0.1, color='r')

for i in range(37):
    if y1[i]>=y2[i]:
        plt.bar(x[i], y1[i], width=0.1, color='r')
        
plt.plot([0,0], [0, 0.5], color='r')
plt.title('H1: mu≠k , H0: mu=k', fontsize=18)
plt.xlabel('Puede estar por arriba o por abajo.');

# %% [markdown]
# # Ejemplo estudio farmaceutico

# %% [markdown]
# Supongamos que una compañia farmaceutica crea un medicamento para manejar la diabetes.
#
# Se sabe que cualquier nivel de hemoglobina A1c por debajo del 5,7% es considerado normal.
# La compañia realiza un estudio de un nuevo medicamento con 100 voluntarios.
#
# + Hipotesis:
# $$H0: \mu \geq 5.7$$
# $$H1: \mu < 5.7$$
#
#
# Los resultados del estudio son $\bar{x}=5.1$, $s=1.6$
#
#
# ¿La prueba es suficiente para rechazar H0?

# %%
import numpy as np

from scipy.stats import t

# %%
# a manita

mu=5.7   # media poblacional

mu_hat=5.1  # media muestral, media del estudio

std_hat=1.6  # std muestra, std del estudio

n=100   # tamaño de la muestra

# %%
t_test = (mu_hat - mu) / (std_hat/np.sqrt(n))

t_test
# Out:
# -3.750000000000003

# %%
dof=n-1 # grados de libertad

dof
# Out:
# 99

# %%
p_value=t(df=dof).cdf(t_test)

p_value
# Out:
# 0.0001489332089038242

# %%
# lo mismo...o casi

from scipy.stats import ttest_1samp

# %%
pacientes=np.random.normal(mu_hat, std_hat, n)

pacientes[:10]
# Out:
# array([4.16190499, 6.79657832, 6.67098477, 6.20753635, 6.53910949,
#        5.57424475, 4.57182328, 3.52282371, 4.79339931, 4.84143329])

# %%
t_test=ttest_1samp(pacientes, mu)

t_test
# Out:
# Ttest_1sampResult(statistic=-1.9373692263161535, pvalue=0.055550120739055825)

# %%
t_test.statistic
# Out:
# -1.9373692263161535

# %%
t_test.pvalue
# Out:
# 0.055550120739055825

# %% [markdown]
# **Conclusion:**
#
# Si buscamos un intervalo de confianza del 99,9%, entonces $umbral=0.001$
#
# El pvalor obtenido es menor que el umbral, por lo tanto podemos rechazar H0.

# %% [markdown]
# # Ejemplo Altura
#
# Estudio media altura humana, 100 individuos.
#
# + Hipotesis:
# $$H0: \mu \leq 1.7$$
# $$H1: \mu > 1.7$$
#
#
# Los resultados del estudio son $\bar{x}=1.72$, $s=0.2$
#
#
# ¿La prueba es suficiente para rechazar H0?

# %%
t_test = (1.72 - 1.7) / (0.2/np.sqrt(100))

p_value= 1 - t(df=99).cdf(t_test)

p_value
# Out:
# 0.15987423706965065

# %%
# con scipy

t_test=ttest_1samp(np.random.normal(1.72, 0.2, 100), 1.7)

t_test
# Out:
# Ttest_1sampResult(statistic=1.5332990848204295, pvalue=0.1283917582001319)

# %%
t_test.pvalue
# Out:
# 0.1283917582001319

# %% [markdown]
# **Conclusion**
#
# Si buscamos un intervalo de confianza del 95%, entonces $umbral=0.05$
#
# El pvalor obtenido es mayor que el umbral, por lo tanto no podemos rechazar H0.
#
# **OJO**
#
# Si buscamos un intervalo de confianza del 80%, entonces $umbral=0.2$
#
# El pvalor obtenido es menor que el umbral, por lo tanto podemos rechazar H0.

# %% [markdown]
# # Z-test
#
# $N(\mu, \sigma)$
#
# supongamos $\sigma=0.25$ , std de la poblacion

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: pandas>=0.25 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: numpy>=1.17 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: scipy>=1.3 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.stats import weightstats as w

# %%
z_score, p_value = w.ztest(np.random.normal(1.72, 0.25, 100), value=1.7)

z_score, p_value
# Out:
# (0.9624537141391543, 0.33582174294897094)

# %%
z_score=(1.72 - 1.7) / (0.25/np.sqrt(100))

z_score
# Out:
# 0.8000000000000007

# %% [markdown]
# # Testeo de hipotesis con 2 muestras
#
# Ya no se estudia una muestra frente a la poblacion, sino que se comparan dos muestras entre si.
#
# En primer lugar, se considera la diferencia de medias:
#
# $$\mu=\mu_1 - \mu_2$$

# %% [markdown]
# El tipo de test cambia:
#
# **1)**
#
# $$H0: \mu \geq 0$$
# $$H1: \mu < 0$$
#
#
# **2)**
#
# $$H0: \mu \leq 0$$
# $$H1: \mu > 0$$
#
#
# **3)**
#
# $$H0: \mu = 0$$
# $$H1: \mu ≠ 0$$

# %% [markdown]
# Por otro lado hay que considerar la independencia de las muestras.
#
# Si son dependientes (matched pairs), entonces se usa el t-test:

# %% [markdown]
# + Welch's t-test
#
#
# $$t=\frac{\bar{x_1} - \bar{x_2}}{\sqrt{\frac{s_1^2}{n_1^2}+\frac{s_2^2}{n_2^2}}}$$

# %%
import pandas as pd

from scipy.stats import ttest_rel  # testeo con dos muestras

from scipy.stats import ttest_ind  # testeo de independencia

# %% [markdown]
# **Hipotesis**
#
# $H0: \mu=0$    (media de las diferencias), (no hay diferencia significativa entre las muestras)
#
# $H1: \mu≠0$   (existe una diferencia significativa entre las muestras)

# %%
b_pres=pd.read_csv('../data/blood_pressure 2.csv')

b_pres.head()
# Out:
#        before       after
# 0  136.713072   92.432965
# 1  134.735618  105.022643
# 2  127.529115   82.242766
# 3  144.527126   93.607172
# 4  124.214720  103.212223

# %%
ttest_rel(b_pres['before'], b_pres['after'])
# Out:
# Ttest_relResult(statistic=27.29184176756024, pvalue=7.303035069607835e-48)

# %%
ttest_1samp(b_pres['before'] - b_pres['after'], 0)
# Out:
# Ttest_1sampResult(statistic=27.29184176756024, pvalue=7.303035069607835e-48)

# %%
b_pres.before.mean(), b_pres.after.mean()
# Out:
# (136.5369525056993, 99.23670008065476)

# %%
b_pres.before.std(), b_pres.after.std()
# Out:
# (10.189313601006058, 9.060199908061609)

# %%
b_pres.before.mean() - b_pres.after.mean()  # mu
# Out:
# 37.30025242504455

# %% [markdown]
# **Conclusion**
#
# El p_Value tiende a cero. Podemos rechazar H0.

# %% [markdown]
# ### independencia
#
# **H0 : Son muestras dependientes**
#
# **H1 : No son muestras dependientes**

# %%
ab_test=pd.read_csv('../data/ab_test.csv')

ab_test.head()
# Out:
#        a      b
# 0   0.27  13.61
# 1   6.08  21.53
# 2  13.74   9.23
# 3   9.70   5.36
# 4   7.00  12.90

# %%
ttest_ind(ab_test.a, ab_test.a)
# Out:
# Ttest_indResult(statistic=0.0, pvalue=1.0)

# %%
ttest_ind(ab_test.a, ab_test.b)  # son independientes
# Out:
# Ttest_indResult(statistic=-2.637533181209767, pvalue=0.009713140852447344)

# %%
ab_test.a.mean(), ab_test.b.mean()
# Out:
# (9.355400000000001, 12.466)

# %%
ab_test.a.std(), ab_test.b.std()
# Out:
# (5.2352701858039135, 6.4912553422560215)

# %%
ttest_ind(ab_test.a, ab_test.b, equal_var=False)
# Out:
# Ttest_indResult(statistic=-2.637533181209767, pvalue=0.009776243024828827)

# %% [markdown]
# **Test de independencia**
#
# + H0 : Completa dependencia (son lo mismo)
# + H1 : son independientes
#
#
# **Conclusion**
#
# Son independientes, el pvalor es menor que el umbral, por lo que podemos rechazar H0.
# Al ser independientes, ya no se usa el t-test, se usa el z-test.
#
#
# **Ahora queremos ver si existe una diferenecia significativa entre a y b.**

# %%
z_score, p_value = w.ztest(ab_test.a, 
                           ab_test.b,
                           
                           value=0,
                           
                           alternative='two-sided',
                           
                           usevar='pooled',
                           ddof=1)

z_score, p_value
# Out:
# (-2.637533181209767, 0.008351145504323936)

# %% [markdown]
# **Conclusion**
#
# El p_value es menor que el umbral, dependiendo del intervalo de confianza, pero siendo asi podemos rechazar H0, y decir que existe una diferencia significativa entre ambas muestras, una pagina web funciona mejor que otra.

# %% [markdown]
# ## Normalidad - Test de Shapiro
#
# **H0: es Normal**
#
#
# **H1 : NO es Normal**

# %%
from scipy.stats import shapiro

# %%
shapiro(ab_test.a)
# Out:
# ShapiroResult(statistic=0.9778033494949341, pvalue=0.46350130438804626)

# %%
shapiro(ab_test.b)
# Out:
# ShapiroResult(statistic=0.9656312465667725, pvalue=0.15291424095630646)

# %% [markdown]
# **normalizando**

# %%
# a mano

a_normal=(ab_test.a - ab_test.a.mean()) / (ab_test.a.std()/np.sqrt(len(ab_test.a)))


a_normal[:10]   # N(0, 1) normal media=0 std=1
# Out:
# 0   -12.271283
# 1    -4.423950
# 2     5.922102
# 3     0.465437
# 4    -3.181344
# 5    -6.193314
# 6    -9.178272
# 7    -2.857185
# 8    -2.776146
# 9   -11.474393
# Name: a, dtype: float64

# %%
ab_test.a[:10]
# Out:
# 0     0.27
# 1     6.08
# 2    13.74
# 3     9.70
# 4     7.00
# 5     4.77
# 6     2.56
# 7     7.24
# 8     7.30
# 9     0.86
# Name: a, dtype: float64

# %%
ab_test.a.mean()
# Out:
# 9.355400000000001

# %%
shapiro(a_normal)
# Out:
# ShapiroResult(statistic=0.9778033494949341, pvalue=0.46350130438804626)

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/iudh/miniforge3/envs/clase/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import StandardScaler

# %%
StandardScaler().fit_transform(ab_test)[:10]
# Out:
# array([[-1.75304036,  0.17802635],
#        [-0.63199291,  1.41051648],
#        [ 0.84601457, -0.50357804],
#        [ 0.06649104, -1.10581753],
#        [-0.45447765,  0.06753797],
#        [-0.8847592 , -0.25459013],
#        [-1.31118173, -0.2748204 ],
#        [-0.40816932,  0.48303654],
#        [-0.39659224, -0.31839328],
#        [-1.63919905,  1.00124261]])

# %%
pd.DataFrame(StandardScaler().fit_transform(ab_test), columns=ab_test.columns).head()
# Out:
#           a         b
# 0 -1.753040  0.178026
# 1 -0.631993  1.410516
# 2  0.846015 -0.503578
# 3  0.066491 -1.105818
# 4 -0.454478  0.067538

# %% [markdown]
# **Intervalos de confianza**

# %%
from scipy.stats import sem   # error estandar

# %%
t.interval(0.99, len(ab_test.a)-1, loc=ab_test.a.mean(), scale=sem(ab_test.a))
# Out:
# (7.371219811062148, 11.339580188937855)

# %%
#help(t.interval)

# %% [markdown]
# **test de proporciones**

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
ab_test['cat']=['a' if i%2 else 'b' for i in range(len(ab_test))]

ab_test.head()
# Out:
#        a      b cat
# 0   0.27  13.61   b
# 1   6.08  21.53   a
# 2  13.74   9.23   b
# 3   9.70   5.36   a
# 4   7.00  12.90   b

# %%
z_score, p_value = proportions_ztest(ab_test['cat'].value_counts()[1], len(ab_test), 0.10)

z_score, p_value
# Out:
# (5.656854249492381, 1.5417257900279904e-08)

# %%
ab_test['cat'].value_counts()
# Out:
# b    25
# a    25
# Name: cat, dtype: int64
